# %%
import pandas as pd
import calplot

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('../data/processed.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['ones'] = [1] * len(df)
df.set_index('timestamp', inplace=True)
df
# Out:
#                     Institution                            Course  actor.id  \
# timestamp
# 2023-07-07 18:55:47         UEF  Advanced Data Management Systems         0
# 2023-07-07 15:21:18         UEF  Advanced Data Management Systems         0
# 2023-07-07 15:08:13         UEF  Advanced Data Management Systems         0
# 2023-07-07 15:08:10         UEF  Advanced Data Management Systems         0
# 2023-07-07 09:03:32         UEF  Advanced Data Management Systems         0
# ...                         ...                               ...       ...
# 2023-06-11 22:57:27         BMU                 Computer Networks       820
# 2023-05-16 00:05:45         BMU                 Computer Networks       799
# 2023-05-12 22:10:50         BMU                 Computer Networks       788
# 2023-02-27 22:45:33         BMU                 Computer Networks       788
# 2023-06-01 21:23:16         BMU                 Computer Networks       810
#
# ...

# %% [markdown]
# # Calplot

# %%
calplot.calplot(data = df['ones'], cmap = 'viridis', figsize = (16, 8), suptitle = "Activity")
# Out:
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# (<Figure size 1600x800 with 2 Axes>,
#  array([<Axes: ylabel='2022'>, <Axes: ylabel='2023'>], dtype=object))
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
# findfont: Font family 'Helvetica' not found.
