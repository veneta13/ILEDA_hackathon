# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns()', None)

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv('/content/sample_data/ILEDA_anonymized.csv').drop_duplicates()
df
# Out:
#        Institution                                  Course actor.id  \
# 0              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 1              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 2              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 3              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 4              UEF  Advanced Data Management Systems (THJ)    aeb0c
# ...            ...                                     ...      ...
# 306723         BMU                                   IT131    87441
# 306724         BMU                                   IT131    1c33c
# 306730         BMU                                   IT131    98607
# 306734         BMU                                   IT131    98607
# 306739         BMU                                   IT131    00c5e
#
#                    timestamp                                   verb.id  \
# 0       2023-07-07T18:55:47Z       http://id.tincanapi.com/verb/viewed
# 1       2023-07-07T15:21:18Z       http://id.tincanapi.com/verb/viewed
# 2       2023-07-07T15:08:13Z       http://id.tincanapi.com/verb/viewed
# 3       2023-07-07T15:08:10Z       http://id.tincanapi.com/verb/viewed
# 4       2023-07-07T09:03:32Z       http://id.tincanapi.com/verb/viewed
# ...                      ...                                       ...
# 306723  2023-06-11T22:57:27Z   http://adlnet.gov/expapi/verbs/answered
# 306724  2023-05-16T00:05:45Z   http://adlnet.gov/expapi/verbs/answered
# 306730  2023-05-12T22:10:50Z  http://adlnet.gov/expapi/verbs/completed
# 306734  2023-02-27T22:45:33Z  http://adlnet.gov/expapi/verbs/completed
# 306739  2023-06-01T21:23:16Z   http://adlnet.gov/expapi/verbs/answered
#
#        verb.display                             object.definition.name  \
# 0            viewed             Advanced Data Management Systems (THJ)
# 1            viewed                  Assignment Instructions: ER & EER
# 2            viewed                           Recording: Intro lecture
# 3            viewed             Advanced Data Management Systems (THJ)
# 4            viewed             Advanced Data Management Systems (THJ)
# ...             ...                                                ...
# 306723     answered                               IT131-T05-Pitanje 13
# 306724     answered                               IT131-T03-Pitanje 15
# 306730    completed                                          IT131-T03
# 306734    completed  Lekcija 2 - Osnove umrežavanja - Tradicionalna...
# 306739     answered                               IT131-T04-Pitanje 20
#
#                                    object.definition.type  \
# 0         http://id.tincanapi.com/activitytype/lms/course
# 1                http://adlnet.gov/expapi/activities/link
# 2                http://adlnet.gov/expapi/activities/link
# 3         http://id.tincanapi.com/activitytype/lms/course
# 4         http://id.tincanapi.com/activitytype/lms/course
# ...                                                   ...
# 306723  http://adlnet.gov/expapi/activities/cmi.intera...
# 306724  http://adlnet.gov/expapi/activities/cmi.intera...
# 306730     http://adlnet.gov/expapi/activities/assessment
# 306734    http://id.tincanapi.com/activitytype/lms/module
# 306739  http://adlnet.gov/expapi/activities/cmi.intera...
#
#                                                   context  \
# 0                                              UEF Moodle
# 1       UEF Moodle > Advanced Data Management Systems ...
# 2       UEF Moodle > Advanced Data Management Systems ...
# 3                                              UEF Moodle
# 4                                              UEF Moodle
# ...                                                   ...
# 306723                 LAMS > test > Pitanje 13 > Attempt
# 306724                 LAMS > test > Pitanje 15 > Attempt
# 306730                                        LAMS > test
# 306734                                      LAMS > 217371
# 306739                 LAMS > test > Pitanje 20 > Attempt
#
#         result.score.scaled  result.success  result.completion
# 0                       NaN           False              False
# 1                       NaN           False              False
# 2                       NaN           False              False
# 3                       NaN           False              False
# 4                       NaN           False              False
# ...                     ...             ...                ...
# 306723                1.000            True               True
# 306724                0.000           False               True
# 306730                0.375            True               True
# 306734                  NaN           False              False
# 306739                0.000           False               True
#
# [299291 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299291 entries, 0 to 306739
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Institution             299291 non-null  object
#  1   Course                  299291 non-null  object
#  2   actor.id                299291 non-null  object
#  3   timestamp               299291 non-null  object
#  4   verb.id                 299291 non-null  object
#  5   verb.display            299291 non-null  object
#  6   object.definition.name  299291 non-null  object
#  7   object.definition.type  299291 non-null  object
#  8   context                 299291 non-null  object
#  9   result.score.scaled     11558 non-null   float64
#  10  result.success          299291 non-null  bool
#  11  result.completion       299291 non-null  bool
# dtypes: bool(2), float64(1), object(9)
# memory usage: 25.7+ MB

# %% [markdown]
# # Preprocessing

# %%
def change_format(x):
  return x.split('/')[-1]

df['verb.id'] = df['verb.id'].apply(change_format)
df
# Out:
#        Institution                                  Course actor.id  \
# 0              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 1              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 2              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 3              UEF  Advanced Data Management Systems (THJ)    aeb0c
# 4              UEF  Advanced Data Management Systems (THJ)    aeb0c
# ...            ...                                     ...      ...
# 306723         BMU                                   IT131    87441
# 306724         BMU                                   IT131    1c33c
# 306730         BMU                                   IT131    98607
# 306734         BMU                                   IT131    98607
# 306739         BMU                                   IT131    00c5e
#
#                    timestamp    verb.id verb.display  \
# 0       2023-07-07T18:55:47Z     viewed       viewed
# 1       2023-07-07T15:21:18Z     viewed       viewed
# 2       2023-07-07T15:08:13Z     viewed       viewed
# 3       2023-07-07T15:08:10Z     viewed       viewed
# 4       2023-07-07T09:03:32Z     viewed       viewed
# ...                      ...        ...          ...
# 306723  2023-06-11T22:57:27Z   answered     answered
# 306724  2023-05-16T00:05:45Z   answered     answered
# 306730  2023-05-12T22:10:50Z  completed    completed
# 306734  2023-02-27T22:45:33Z  completed    completed
# 306739  2023-06-01T21:23:16Z   answered     answered
#
#                                    object.definition.name  \
# 0                  Advanced Data Management Systems (THJ)
# 1                       Assignment Instructions: ER & EER
# 2                                Recording: Intro lecture
# 3                  Advanced Data Management Systems (THJ)
# 4                  Advanced Data Management Systems (THJ)
# ...                                                   ...
# 306723                               IT131-T05-Pitanje 13
# 306724                               IT131-T03-Pitanje 15
# 306730                                          IT131-T03
# 306734  Lekcija 2 - Osnove umrežavanja - Tradicionalna...
# 306739                               IT131-T04-Pitanje 20
#
#                                    object.definition.type  \
# 0         http://id.tincanapi.com/activitytype/lms/course
# 1                http://adlnet.gov/expapi/activities/link
# 2                http://adlnet.gov/expapi/activities/link
# 3         http://id.tincanapi.com/activitytype/lms/course
# 4         http://id.tincanapi.com/activitytype/lms/course
# ...                                                   ...
# 306723  http://adlnet.gov/expapi/activities/cmi.intera...
# 306724  http://adlnet.gov/expapi/activities/cmi.intera...
# 306730     http://adlnet.gov/expapi/activities/assessment
# 306734    http://id.tincanapi.com/activitytype/lms/module
# 306739  http://adlnet.gov/expapi/activities/cmi.intera...
#
#                                                   context  \
# 0                                              UEF Moodle
# 1       UEF Moodle > Advanced Data Management Systems ...
# 2       UEF Moodle > Advanced Data Management Systems ...
# 3                                              UEF Moodle
# 4                                              UEF Moodle
# ...                                                   ...
# 306723                 LAMS > test > Pitanje 13 > Attempt
# 306724                 LAMS > test > Pitanje 15 > Attempt
# 306730                                        LAMS > test
# 306734                                      LAMS > 217371
# 306739                 LAMS > test > Pitanje 20 > Attempt
#
#         result.score.scaled  result.success  result.completion
# 0                       NaN           False              False
# 1                       NaN           False              False
# 2                       NaN           False              False
# 3                       NaN           False              False
# 4                       NaN           False              False
# ...                     ...             ...                ...
# 306723                1.000            True               True
# 306724                0.000           False               True
# 306730                0.375            True               True
# 306734                  NaN           False              False
# 306739                0.000           False               True
#
# [299291 rows x 12 columns]

# %%
courses_dict = {
    'Ihminen ja vuorovaikutteinen teknologia': 'Human Factors of Interactive Technology',
    'Advanced Data Management Systems (THJ)': 'Advanced Data Management Systems',
    'Проектиране на човеко-машинен интерфейс, летен семестър 2022/2023': 'Human-computer interaction',
    'Електронно обучение, летен семестър 2022/2023': 'e-Learning',
    'ARQUITECTURA DE COMPUTADORES': 'Computer Architecture',
    'APLICACIONES WEB': 'Web Applications',
    'CS120': 'Computer Networks',
    'IT131': 'Computer Organization'
}

df.replace({"Course": courses_dict}, inplace=True)

# %%
different_verbs = df[df['verb.id'] != df['verb.display']][['verb.id', 'verb.display']]

# %%
different_verbs.value_counts()
# Out:
# verb.id  verb.display
# receive  received              6582
# start    started               4400
# scored   attained grade for    4236
# submit   submitted             1481
# create   created                931
# join     joined                 136
# leave    left                    34
# dtype: int64

# %% [markdown]
# 1:1 mapping in the 2 columns. Remove the 2nd one.

# %%
df = df.drop('verb.display', axis=1)

# %%
actors = df['actor.id'].value_counts()
df[df['actor.id'].isin(actors[actors == 1].index)]
# Out:
#        Institution                                   Course actor.id  \
# 15773          UEF         Advanced Data Management Systems    0954e
# 21296          UEF  Human Factors of Interactive Technology    1f3e4
# 75157          UEF  Human Factors of Interactive Technology    de417
# 168316          SU               Human-computer interaction    e4f51
# 169391          SU               Human-computer interaction    fb51a
# 185028          SU                               e-Learning    6ed85
# 189817          SU                               e-Learning    cd331
# 189818          SU                               e-Learning    47d0e
# 189819          SU                               e-Learning    7dd01
# 196531          UL                    Computer Architecture    297c3
# 291965          UL                         Web Applications    1ad31
#
#                    timestamp    verb.id  \
# 15773   2023-03-28T07:32:41Z     viewed
# 21296   2023-06-05T10:40:27Z     viewed
# 75157   2023-05-05T09:01:17Z     viewed
# 168316  2023-02-22T08:53:54Z     viewed
# 169391  2023-01-31T11:41:27Z     viewed
# 185028  2023-03-28T13:40:16Z  completed
# 189817  2023-03-13T18:59:23Z  completed
# 189818  2023-03-13T18:59:23Z  completed
# 189819  2023-03-13T18:59:21Z  completed
# 196531  2023-08-10T06:51:25Z     viewed
# 291965  2023-02-10T13:22:53Z     viewed
#
#                                    object.definition.name  \
# 15773              Advanced Data Management Systems (THJ)
# 21296             Ihminen ja vuorovaikutteinen teknologia
# 75157             Ihminen ja vuorovaikutteinen teknologia
# 168316  Как искате да се провеждат лекциите: присъстве...
# 169391  Проектиране на човеко-машинен интерфейс, летен...
# 185028  Тест за установяване на предварителното запозн...
# 189817  Тест за установяване на предварителното запозн...
# 189818  Тест за установяване на предварителното запозн...
# 189819  Тест за установяване на предварителното запозн...
# 196531  ARQUITECTURA DE COMPUTADORES - Graduado en Ing...
# 291965  APLICACIONES WEB - Graduado en Ingeniería Info...
#
#                                  object.definition.type  \
# 15773   http://id.tincanapi.com/activitytype/lms/course
# 21296   http://id.tincanapi.com/activitytype/lms/course
# 75157   http://id.tincanapi.com/activitytype/lms/course
# 168316  http://id.tincanapi.com/activitytype/lms/module
# 169391  http://id.tincanapi.com/activitytype/lms/course
# 185028  http://id.tincanapi.com/activitytype/lms/module
# 189817  http://id.tincanapi.com/activitytype/lms/module
# 189818  http://id.tincanapi.com/activitytype/lms/module
# 189819  http://id.tincanapi.com/activitytype/lms/module
# 196531  http://id.tincanapi.com/activitytype/lms/course
# 291965  http://id.tincanapi.com/activitytype/lms/course
#
#                                                   context  \
# 15773                                          UEF Moodle
# 21296                                          UEF Moodle
# 75157                                          UEF Moodle
# 168316  ILEDA Project > Проектиране на човеко-машинен ...
# 169391                                      ILEDA Project
# 185028  ILEDA Project > Електронно обучение, летен сем...
# 189817  ILEDA Project > Електронно обучение, летен сем...
# 189818  ILEDA Project > Електронно обучение, летен сем...
# 189819  ILEDA Project > Електронно обучение, летен сем...
# 196531                                           New Site
# 291965                                           New Site
#
#         result.score.scaled  result.success  result.completion
# 15773                   NaN           False              False
# 21296                   NaN           False              False
# 75157                   NaN           False              False
# 168316                  NaN           False              False
# 169391                  NaN           False              False
# 185028                  NaN           False              False
# 189817                  NaN           False              False
# 189818                  NaN           False              False
# 189819                  NaN           False              False
# 196531                  NaN           False              False
# 291965                  NaN           False              False

# %%
df.sort_values(by='timestamp')
# Out:
#        Institution                 Course actor.id             timestamp  \
# 292146          UL       Web Applications    23aa8  2022-08-09T09:34:44Z
# 292145          UL       Web Applications    13981  2022-08-09T20:51:57Z
# 292144          UL       Web Applications    23aa8  2022-08-16T16:43:02Z
# 292143          UL       Web Applications    23aa8  2022-08-17T12:47:30Z
# 271397          UL  Computer Architecture    1757f  2022-08-17T22:44:48Z
# ...            ...                    ...      ...                   ...
# 271400          UL       Web Applications    8d7d5  2023-08-11T07:51:13Z
# 271399          UL       Web Applications    e62e6  2023-08-11T07:51:13Z
# 271402          UL       Web Applications    54088  2023-08-11T07:51:13Z
# 271401          UL       Web Applications    c015e  2023-08-11T07:51:13Z
# 271398          UL       Web Applications    be625  2023-08-11T07:51:20Z
#
#        verb.id                             object.definition.name  \
# 292146  viewed  APLICACIONES WEB - Graduado en Ingeniería Info...
# 292145  viewed  APLICACIONES WEB - Graduado en Ingeniería Info...
# 292144  viewed  APLICACIONES WEB - Graduado en Ingeniería Info...
# 292143  viewed  APLICACIONES WEB - Graduado en Ingeniería Info...
# 271397  viewed  ARQUITECTURA DE COMPUTADORES - Graduado en Ing...
# ...        ...                                                ...
# 271400  scored                           Práctica final - Entrega
# 271399  scored                           Práctica final - Entrega
# 271402  scored                           Práctica final - Entrega
# 271401  scored                           Práctica final - Entrega
# 271398  viewed  APLICACIONES WEB - Graduado en Ingeniería Info...
#
#                                  object.definition.type  \
# 292146  http://id.tincanapi.com/activitytype/lms/course
# 292145  http://id.tincanapi.com/activitytype/lms/course
# 292144  http://id.tincanapi.com/activitytype/lms/course
# 292143  http://id.tincanapi.com/activitytype/lms/course
# 271397  http://id.tincanapi.com/activitytype/lms/course
# ...                                                 ...
# 271400   http://adlnet.gov/expapi/activities/assessment
# 271399   http://adlnet.gov/expapi/activities/assessment
# 271402   http://adlnet.gov/expapi/activities/assessment
# 271401   http://adlnet.gov/expapi/activities/assessment
# 271398  http://id.tincanapi.com/activitytype/lms/course
#
#                                                   context  \
# 292146                                           New Site
# 292145                                           New Site
# 292144                                           New Site
# 292143                                           New Site
# 271397                                           New Site
# ...                                                   ...
# 271400  New Site > APLICACIONES WEB - Graduado en Inge...
# 271399  New Site > APLICACIONES WEB - Graduado en Inge...
# 271402  New Site > APLICACIONES WEB - Graduado en Inge...
# 271401  New Site > APLICACIONES WEB - Graduado en Inge...
# 271398                                           New Site
#
#         result.score.scaled  result.success  result.completion
# 292146                  NaN           False              False
# 292145                  NaN           False              False
# 292144                  NaN           False              False
# 292143                  NaN           False              False
# 271397                  NaN           False              False
# ...                     ...             ...                ...
# 271400                0.087            True               True
# 271399                0.087            True               True
# 271402                0.087            True               True
# 271401                0.087            True               True
# 271398                  NaN           False              False
#
# [299291 rows x 11 columns]

# %% [markdown]
# The data is from 09.08.2022 to 11.08.2023

# %%
def get_sec_day(x):
  return int(x)*24*60*60

def get_days_month(x):
  thirty_one = [1,3,5,7,8,10,12]
  thirty = [4,6,9,11]
  twenty_eight = [2]

  days = 0
  for i in range(1,int(x)+1):
    if i in thirty_one:
      days += 31
    if i in thirty:
      days += 30
    if i in twenty_eight:
      days += 28

  return days

def get_sec_month(x):
  x = get_days_month(x)
  return x*24*60*60

def get_sec_year(x):
  return int(x)*365*24*60*60

def get_sec_hour(x):
  return int(x)*60*60

def get_sec_minute(x):
  return int(x)*60

def timestamp_to_seconds(timestamp):
  date, hour = timestamp.split('-'), timestamp.split('-')[-1][3:-1]
  date[-1] = date[-1][:2]
  hour = hour.split(':')

  total_seconds = get_sec_year(date[0]) + get_sec_month(date[1]) + get_sec_day(date[2]) + get_sec_hour(hour[0]) + get_sec_minute(hour[1]) + int(hour[2])
  return total_seconds

df['timestamp'] = df['timestamp'].apply(timestamp_to_seconds)
df['timestamp'] = df['timestamp'] - min(df['timestamp'])

# %%
df.sort_values(by=['timestamp'])
# Out:
#        Institution                 Course actor.id  timestamp verb.id  \
# 292146          UL       Web Applications    23aa8          0  viewed
# 292145          UL       Web Applications    13981      40633  viewed
# 292144          UL       Web Applications    23aa8     630498  viewed
# 292143          UL       Web Applications    23aa8     702766  viewed
# 271397          UL  Computer Architecture    1757f     738604  viewed
# ...            ...                    ...      ...        ...     ...
# 271400          UL       Web Applications    8d7d5   31702589  scored
# 271399          UL       Web Applications    e62e6   31702589  scored
# 271402          UL       Web Applications    54088   31702589  scored
# 271401          UL       Web Applications    c015e   31702589  scored
# 271398          UL       Web Applications    be625   31702596  viewed
#
#                                    object.definition.name  \
# 292146  APLICACIONES WEB - Graduado en Ingeniería Info...
# 292145  APLICACIONES WEB - Graduado en Ingeniería Info...
# 292144  APLICACIONES WEB - Graduado en Ingeniería Info...
# 292143  APLICACIONES WEB - Graduado en Ingeniería Info...
# 271397  ARQUITECTURA DE COMPUTADORES - Graduado en Ing...
# ...                                                   ...
# 271400                           Práctica final - Entrega
# 271399                           Práctica final - Entrega
# 271402                           Práctica final - Entrega
# 271401                           Práctica final - Entrega
# 271398  APLICACIONES WEB - Graduado en Ingeniería Info...
#
#                                  object.definition.type  \
# 292146  http://id.tincanapi.com/activitytype/lms/course
# 292145  http://id.tincanapi.com/activitytype/lms/course
# 292144  http://id.tincanapi.com/activitytype/lms/course
# 292143  http://id.tincanapi.com/activitytype/lms/course
# 271397  http://id.tincanapi.com/activitytype/lms/course
# ...                                                 ...
# 271400   http://adlnet.gov/expapi/activities/assessment
# 271399   http://adlnet.gov/expapi/activities/assessment
# 271402   http://adlnet.gov/expapi/activities/assessment
# 271401   http://adlnet.gov/expapi/activities/assessment
# 271398  http://id.tincanapi.com/activitytype/lms/course
#
#                                                   context  \
# 292146                                           New Site
# 292145                                           New Site
# 292144                                           New Site
# 292143                                           New Site
# 271397                                           New Site
# ...                                                   ...
# 271400  New Site > APLICACIONES WEB - Graduado en Inge...
# 271399  New Site > APLICACIONES WEB - Graduado en Inge...
# 271402  New Site > APLICACIONES WEB - Graduado en Inge...
# 271401  New Site > APLICACIONES WEB - Graduado en Inge...
# 271398                                           New Site
#
#         result.score.scaled  result.success  result.completion
# 292146                  NaN           False              False
# 292145                  NaN           False              False
# 292144                  NaN           False              False
# 292143                  NaN           False              False
# 271397                  NaN           False              False
# ...                     ...             ...                ...
# 271400                0.087            True               True
# 271399                0.087            True               True
# 271402                0.087            True               True
# 271401                0.087            True               True
# 271398                  NaN           False              False
#
# [299291 rows x 11 columns]

# %%
def change_object_definition(object_def):
  return object_def.split('/')[-1]

df['object.definition.type'] = df['object.definition.type'].apply(change_object_definition)

# %%
df['object.definition.type'].value_counts()
# Out:
# course             102682
# cmi.interaction     33546
# resource            30790
# discussion          25061
# module              23838
# quiz                21083
# assessment          20319
# attempt             14749
# forum-topic         11768
# link                10281
# page                 2561
# review               2322
# meeting               197
# survey                 88
# lesson                  6
# Name: object.definition.type, dtype: int64

# %%
actors_dict = dict()
course_dict = dict()
institution_dict = dict()

for actor in set(df['actor.id']):
  actors_dict[actor] = df[df['actor.id'] == actor].sort_values(by='timestamp')

for course in set(df['Course']):
  course_dict[course] = df[df['Course'] == course].sort_values(by='timestamp')

for institution in set(df['Institution']):
  institution_dict[institution] = df[df['Institution'] == institution].sort_values(by='timestamp')

# %%
institution_dict['SU']
# Out:
#        Institution                      Course actor.id  timestamp verb.id  \
# 169433          SU  Human-computer interaction    b4324   14807381  viewed
# 169432          SU  Human-computer interaction    b4324   14807413  viewed
# 169431          SU  Human-computer interaction    190c5   14808024  viewed
# 169430          SU  Human-computer interaction    b5cad   14808935  viewed
# 169429          SU  Human-computer interaction    b5cad   14808939  viewed
# ...            ...                         ...      ...        ...     ...
# 153576          SU  Human-computer interaction    704aa   24872111  viewed
# 153575          SU  Human-computer interaction    704aa   24872226  viewed
# 153574          SU  Human-computer interaction    704aa   24872275  viewed
# 153573          SU  Human-computer interaction    704aa   24872336  viewed
# 153572          SU  Human-computer interaction    704aa   24872349  viewed
#
#                                    object.definition.name  \
# 169433  Проектиране на човеко-машинен интерфейс, летен...
# 169432  Проектиране на човеко-машинен интерфейс, летен...
# 169431  Проектиране на човеко-машинен интерфейс, летен...
# 169430  Проектиране на човеко-машинен интерфейс, летен...
# 169429                                          Обявления
# ...                                                   ...
# 153576  Проектиране на човеко-машинен интерфейс, летен...
# 153575  Записване за защитите на проекти по ПЧМИ - Мол...
# 153574  Проектиране на човеко-машинен интерфейс, летен...
# 153573  Проектиране на човеко-машинен интерфейс, летен...
# 153572  Проектиране на човеко-машинен интерфейс, летен...
#
#        object.definition.type  \
# 169433                 course
# 169432                 course
# 169431                 course
# 169430                 course
# 169429            forum-topic
# ...                       ...
# 153576                 course
# 153575                   link
# 153574                 course
# 153573                 course
# 153572                 course
#
#                                                   context  \
# 169433                                      ILEDA Project
# 169432                                      ILEDA Project
# 169431                                      ILEDA Project
# 169430                                      ILEDA Project
# 169429  ILEDA Project > Проектиране на човеко-машинен ...
# ...                                                   ...
# 153576                                      ILEDA Project
# 153575  ILEDA Project > Проектиране на човеко-машинен ...
# 153574                                      ILEDA Project
# 153573                                      ILEDA Project
# 153572                                      ILEDA Project
#
#         result.score.scaled  result.success  result.completion
# 169433                  NaN           False              False
# 169432                  NaN           False              False
# 169431                  NaN           False              False
# 169430                  NaN           False              False
# 169429                  NaN           False              False
# ...                     ...             ...                ...
# 153576                  NaN           False              False
# 153575                  NaN           False              False
# 153574                  NaN           False              False
# 153573                  NaN           False              False
# 153572                  NaN           False              False
#
# [42319 rows x 11 columns]

# %%
df['result.score.scaled'] = df['result.score.scaled'].fillna(-1)
df
# Out:
#        Institution                            Course actor.id  timestamp  \
# 0              UEF  Advanced Data Management Systems    aeb0c   28718463
# 1              UEF  Advanced Data Management Systems    aeb0c   28705594
# 2              UEF  Advanced Data Management Systems    aeb0c   28704809
# 3              UEF  Advanced Data Management Systems    aeb0c   28704806
# 4              UEF  Advanced Data Management Systems    aeb0c   28682928
# ...            ...                               ...      ...        ...
# 306723         BMU             Computer Organization    87441   26400163
# 306724         BMU             Computer Organization    1c33c   24157861
# 306730         BMU             Computer Organization    98607   23891766
# 306734         BMU             Computer Organization    98607   17241049
# 306739         BMU             Computer Organization    00c5e   25530512
#
#           verb.id                             object.definition.name  \
# 0          viewed             Advanced Data Management Systems (THJ)
# 1          viewed                  Assignment Instructions: ER & EER
# 2          viewed                           Recording: Intro lecture
# 3          viewed             Advanced Data Management Systems (THJ)
# 4          viewed             Advanced Data Management Systems (THJ)
# ...           ...                                                ...
# 306723   answered                               IT131-T05-Pitanje 13
# 306724   answered                               IT131-T03-Pitanje 15
# 306730  completed                                          IT131-T03
# 306734  completed  Lekcija 2 - Osnove umrežavanja - Tradicionalna...
# 306739   answered                               IT131-T04-Pitanje 20
#
#        object.definition.type  \
# 0                      course
# 1                        link
# 2                        link
# 3                      course
# 4                      course
# ...                       ...
# 306723        cmi.interaction
# 306724        cmi.interaction
# 306730             assessment
# 306734                 module
# 306739        cmi.interaction
#
#                                                   context  \
# 0                                              UEF Moodle
# 1       UEF Moodle > Advanced Data Management Systems ...
# 2       UEF Moodle > Advanced Data Management Systems ...
# 3                                              UEF Moodle
# 4                                              UEF Moodle
# ...                                                   ...
# 306723                 LAMS > test > Pitanje 13 > Attempt
# 306724                 LAMS > test > Pitanje 15 > Attempt
# 306730                                        LAMS > test
# 306734                                      LAMS > 217371
# 306739                 LAMS > test > Pitanje 20 > Attempt
#
#         result.score.scaled  result.success  result.completion
# 0                    -1.000           False              False
# 1                    -1.000           False              False
# 2                    -1.000           False              False
# 3                    -1.000           False              False
# 4                    -1.000           False              False
# ...                     ...             ...                ...
# 306723                1.000            True               True
# 306724                0.000           False               True
# 306730                0.375            True               True
# 306734               -1.000           False              False
# 306739                0.000           False               True
#
# [299291 rows x 11 columns]

# %%
df[df['object.definition.name'].str.contains('Recording')]

# %%
df[df['object.definition.type'] == 'link']

# %%
df[df['object.definition.type'] == 'cmi.interaction'][['verb.id', 'object.definition.type']].value_counts()
# Out:
# verb.id   object.definition.type
# answered  cmi.interaction           33546
# dtype: int64

# %%
df['verb.id'].value_counts()
# Out:
# viewed       229721
# answered      33546
# completed     18224
# receive        6582
# start          4400
# scored         4236
# submit         1481
# create          931
# join            136
# leave            34
# Name: verb.id, dtype: int64

# %% [markdown]
# cmi.interaction == answered

# %%
len(set(df['actor.id'])) # 829 people
# Out:
# 829

# %%
df[['verb.id', 'object.definition.type']].value_counts()
# Out:
# verb.id    object.definition.type
# viewed     course                    102682
# answered   cmi.interaction            33546
# viewed     resource                   30790
#            discussion                 24130
#            attempt                    14749
#            quiz                       13171
#            module                     13111
#            forum-topic                11768
# completed  module                     10727
# viewed     link                       10281
#            assessment                  6369
# completed  assessment                  5697
# receive    quiz                        4260
# scored     assessment                  4236
# viewed     page                        2561
# start      assessment                  2548
# receive    review                      2322
# start      quiz                        1852
# completed  quiz                        1800
# submit     assessment                  1469
# create     discussion                   931
# join       meeting                      136
# viewed     survey                        76
# leave      meeting                       34
# viewed     meeting                       27
# submit     survey                        12
# viewed     lesson                         6
# dtype: int64

# %%
df['object.definition.name'].value_counts()
# Out:
# Ihminen ja vuorovaikutteinen teknologia                              34133
# ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática    30135
# Attempt                                                              14749
# Електронно обучение, летен семестър 2022/2023                        10880
# Проектиране на човеко-машинен интерфейс, летен семестър 2022/2023    10551
#                                                                      ...
# Questionnaire turn                                                       1
# OpenMP                                                                   1
# Запис на лекцията от миналата година                                     1
# Qt and Pointers                                                          1
# Проектиране на съвместна работа                                          1
# Name: object.definition.name, Length: 1549, dtype: int64

# %%
# !pip install googletrans==4.0.0-rc1
from googletrans import Translator
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.10/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.7.22)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2023.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
translator = Translator()

# Text to be translated
text_to_translate = "Hola, ¿cómo estás?"

# Translate to English
translated_text = translator.translate(text_to_translate, dest='en')

# Print the translated text
print("Original text:", text_to_translate)
print("Translated text:", translated_text.text)
# Out:
# Original text: Hola, ¿cómo estás?
# Translated text: Hello how are you?

# %%
translated_object_def = [translator.translate(text).text for text in list(set(df['object.definition.name']))[0:10]]
translated_object_def
# Out:
# ['CS120-T04-Walking 3',
#  'What of the following are the following criteria for learning?',
#  'Presentation: Maxim Piles',
#  'Practical Delivery 7 - Animal Crossing Cards Axios',
#  'Exercise 11- Accessibility, Adaptation and Personalization',
#  'IT131-T01-Walk 46',
#  'Cyrillic',
#  'Exercise 4 - Ideas and Prototypes',
#  'Upload images demonstrating that you have been able to execute the program on your computer with the new file ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ Upload images showing that you have aable to run the program on your computer with the new fille.',
#  'Prior evaluation']

# %% [markdown]
# Not gonna work ;(. Google иска пари за това

# %%
df[['context', 'object.definition.type']].value_counts()
# Out:
# context                                                                                                    object.definition.type
# UEF Moodle                                                                                                 course                    40826
# New Site                                                                                                   course                    40425
# ILEDA Project                                                                                              course                    21431
# UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > RyhmÃ¤tyÃ¶alue                                      discussion                20830
# UEF Moodle > Ihminen ja vuorovaikutteinen teknologia                                                       module                    13013
#                                                                                                                                      ...
# New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G2 > Attempt  quiz                          3
# ILEDA Project > Електронно обучение, летен семестър 2022/2023                                              page                          2
# New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G3 > Attempt  quiz                          2
# ILEDA Project > Проектиране на човеко-машинен интерфейс, летен семестър 2022/2023                          quiz                          1
# New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G4 > Attempt  quiz                          1
# Length: 290, dtype: int64

# %%
df[df['context'].str.contains('Attempt')]['context'].value_counts()
# Out:
# UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 9 > Attempt                                                                                    6226
# UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 14 > Attempt                                                                                   3520
# UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 4 > Attempt                                                                                    2236
# UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 12 > Attempt                                                                                   2166
# New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Exercise 1.1- Comparing Computer Performance (deadline: 21.04.2023) > Attempt    1890
#                                                                                                                                                                 ...
# LAMS > test > Pitanje 46 > Attempt                                                                                                                                 7
# LAMS > test > Pitanje 49 > Attempt                                                                                                                                 6
# LAMS > test > Pitanje 48 > Attempt                                                                                                                                 6
# LAMS > test > Pitanje 50 > Attempt                                                                                                                                 5
# LAMS > test > Pitanje 47 > Attempt                                                                                                                                 4
# Name: context, Length: 100, dtype: int64

# %%
def change_attempt_context(context):
  return ' > '.join(context.split(' > ')[-2:])
#df[df['context'].str.contains('Attempt')]['context'] = df[df['context'].str.contains('Attempt')]['context'].apply(change_attempt_context)
# Out:
# <ipython-input-39-c04ee200b025>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['context'].str.contains('Attempt')]['context'] = df[df['context'].str.contains('Attempt')]['context'].apply(change_attempt_context)

# %%
df['context'].loc[df['context'].str.contains('Attempt')] = df[df['context'].str.contains('Attempt')]['context'].apply(change_attempt_context)
df['context']
# Out:
# <ipython-input-41-88802cef492c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['context'].loc[df['context'].str.contains('Attempt')] = df[df['context'].str.contains('Attempt')]['context'].apply(change_attempt_context)
# 0                                                UEF Moodle
# 1         UEF Moodle > Advanced Data Management Systems ...
# 2         UEF Moodle > Advanced Data Management Systems ...
# 3                                                UEF Moodle
# 4                                                UEF Moodle
#                                 ...
# 306723                                 Pitanje 13 > Attempt
# 306724                                 Pitanje 15 > Attempt
# 306730                                          LAMS > test
# 306734                                        LAMS > 217371
# 306739                                 Pitanje 20 > Attempt
# Name: context, Length: 299291, dtype: object

# %%
df[df['context'].str.contains('Attempt')]['context']
# Out:
# 763         Self-assessment: SQL > Attempt
# 891       Self-assessment: NoSQL > Attempt
# 892       Self-assessment: NoSQL > Attempt
# 893       Self-assessment: NoSQL > Attempt
# 894       Self-assessment: NoSQL > Attempt
#                         ...
# 306715                Pitanje 36 > Attempt
# 306718                Pitanje 33 > Attempt
# 306723                Pitanje 13 > Attempt
# 306724                Pitanje 15 > Attempt
# 306739                Pitanje 20 > Attempt
# Name: context, Length: 39928, dtype: object

# %%
set(df['context'])
# Out:
# {'3.1. Multilevel caching > Attempt',
#  'CS120-T01 > Attempt',
#  'CS120-T02 > Attempt',
#  'CS120-T03 > Attempt',
#  'CS120-T04 > Attempt',
#  'CS120-T05 > Attempt',
#  'Defence quizz Lab Assignment #3 > Attempt',
#  'Defence quizz lab Assignment #4 > Attempt',
#  'Defence quizz lab Assignment #6 > Attempt',
#  'Exercise 1.1- Comparing Computer Performance (deadline: 21.04.2023) > Attempt',
#  'Exercise 1.2- CPU Performance Equation (deadline: 21.04.2023) > Attempt',
#  'Exercise 2.1. Pipelining > Attempt',
#  'ILEDA Project',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Задание 3.1: Критерии за оценка на курс',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Комбиниран тест за основни знания върху Тема 3 и Тема 5',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Обявления от преподавателите',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > ПОВТОРЕН Тест Електронно обучение',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Тест Електронно обучение',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Тест за установяване на запознаването с материалите за седмицата',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Тест за установяване на предварителното запознаване с материалите за седмицата',
#  'ILEDA Project > Електронно обучение, летен семестър 2022/2023 > Търся си екип за финалното задание',
#  'ILEDA Project > Проектиране на човеко-машинен интерфейс, летен семестър 2022/2023',
#  'ILEDA Project > Проектиране на човеко-машинен интерфейс, летен семестър 2022/2023 > Обявления',
#  'IT131-T01 > Attempt',
#  'IT131-T02 > Attempt',
#  'IT131-T03 > Attempt',
#  'IT131-T04 > Attempt',
#  'IT131-T05 > Attempt',
#  'Initial evaluation quizz lab assignment #1 > Attempt',
#  'Initial evaluation quizz lab assignment #2 > Attempt',
#  'Initial evaluation quizz lab assignment #3 > Attempt',
#  'Initial evaluation quizz lab assignment #4.1 > Attempt',
#  'Initial evaluation quizz lab assignment #4.2 > Attempt',
#  'Initial evaluation quizz lab assignment #4.3 > Attempt',
#  'Initial evaluation quizz lab assignment #4.4 > Attempt',
#  'LAMS > 216079',
#  'LAMS > 217371',
#  'LAMS > 218873',
#  'LAMS > 218946',
#  'LAMS > 219720',
#  'LAMS > 219945',
#  'LAMS > 220299',
#  'LAMS > 220491',
#  'LAMS > 220622',
#  'LAMS > 220647',
#  'LAMS > 220870',
#  'LAMS > 221045',
#  'LAMS > 221218',
#  'LAMS > 221648',
#  'LAMS > 221651',
#  'LAMS > 221888',
#  'LAMS > 221910',
#  'LAMS > 221952',
#  'LAMS > 221958',
#  'LAMS > 222118',
#  'LAMS > 222135',
#  'LAMS > 222218',
#  'LAMS > 222249',
#  'LAMS > 222423',
#  'LAMS > 222487',
#  'LAMS > 222923',
#  'LAMS > 223136',
#  'LAMS > 223529',
#  'LAMS > test',
#  'Lab assignment 4 quiz > Attempt',
#  'Lab assignment 4 quiz English > Attempt',
#  'Lab assignment 4 quiz GP3 English > Attempt',
#  'Lab#6 Defense G1 > Attempt',
#  'Lab#6 Defense G2 > Attempt',
#  'Lab#6 Defense G3 > Attempt',
#  'Lab#6 Defense G4 > Attempt',
#  'New Site',
#  'New Site > APLICACIONES WEB - Graduado en Ingeniería Informática',
#  'New Site > APLICACIONES WEB - Graduado en Ingeniería Informática > Avisos',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > 3.1. Multilevel caching',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Avisos',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Defence quizz Lab Assignment #3',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Defence quizz lab Assignment #4',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Defence quizz lab Assignment #6',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Exercise 1.1- Comparing Computer Performance (deadline: 21.04.2023)',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Exercise 1.2- CPU Performance Equation (deadline: 21.04.2023)',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Exercise 2.1. Pipelining',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #1',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #2',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #3',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #4.1',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #4.2',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #4.3',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Initial evaluation quizz lab assignment #4.4',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab assignment 4 quiz',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab assignment 4 quiz English',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab assignment 4 quiz GP3 English',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G1',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G2',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G3',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Lab#6 Defense G4',
#  'New Site > ARQUITECTURA DE COMPUTADORES - Graduado en Ingeniería Informática > Quiz Lab#6',
#  'Pitanje 1 > Attempt',
#  'Pitanje 10 > Attempt',
#  'Pitanje 11 > Attempt',
#  'Pitanje 12 > Attempt',
#  'Pitanje 13 > Attempt',
#  'Pitanje 14 > Attempt',
#  'Pitanje 15 > Attempt',
#  'Pitanje 16 > Attempt',
#  'Pitanje 17 > Attempt',
#  'Pitanje 18 > Attempt',
#  'Pitanje 19 > Attempt',
#  'Pitanje 2 > Attempt',
#  'Pitanje 20 > Attempt',
#  'Pitanje 21 > Attempt',
#  'Pitanje 22 > Attempt',
#  'Pitanje 23 > Attempt',
#  'Pitanje 24 > Attempt',
#  'Pitanje 25 > Attempt',
#  'Pitanje 26 > Attempt',
#  'Pitanje 27 > Attempt',
#  'Pitanje 28 > Attempt',
#  'Pitanje 29 > Attempt',
#  'Pitanje 3 > Attempt',
#  'Pitanje 30 > Attempt',
#  'Pitanje 31 > Attempt',
#  'Pitanje 32 > Attempt',
#  'Pitanje 33 > Attempt',
#  'Pitanje 34 > Attempt',
#  'Pitanje 35 > Attempt',
#  'Pitanje 36 > Attempt',
#  'Pitanje 37 > Attempt',
#  'Pitanje 38 > Attempt',
#  'Pitanje 39 > Attempt',
#  'Pitanje 4 > Attempt',
#  'Pitanje 40 > Attempt',
#  'Pitanje 41 > Attempt',
#  'Pitanje 42 > Attempt',
#  'Pitanje 43 > Attempt',
#  'Pitanje 44 > Attempt',
#  'Pitanje 45 > Attempt',
#  'Pitanje 46 > Attempt',
#  'Pitanje 47 > Attempt',
#  'Pitanje 48 > Attempt',
#  'Pitanje 49 > Attempt',
#  'Pitanje 5 > Attempt',
#  'Pitanje 50 > Attempt',
#  'Pitanje 6 > Attempt',
#  'Pitanje 7 > Attempt',
#  'Pitanje 8 > Attempt',
#  'Pitanje 9 > Attempt',
#  'Quiz Lab#6 > Attempt',
#  'Self-assessment: Data analysis > Attempt',
#  'Self-assessment: ER & EER > Attempt',
#  'Self-assessment: NoSQL > Attempt',
#  'Self-assessment: Normalization > Attempt',
#  'Self-assessment: SQL > Attempt',
#  'Self-assessment: Security > Attempt',
#  'Self-assessment: Transactions & Triggers & Optimization > Attempt',
#  'TehtÃ¤vÃ¤ 12 > Attempt',
#  'TehtÃ¤vÃ¤ 14 > Attempt',
#  'TehtÃ¤vÃ¤ 18 > Attempt',
#  'TehtÃ¤vÃ¤ 2 > Attempt',
#  'TehtÃ¤vÃ¤ 4 > Attempt',
#  'TehtÃ¤vÃ¤ 9 > Attempt',
#  'UEF Moodle',
#  'UEF Moodle > Advanced Data Management Systems (THJ)',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > News',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: Data analysis',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: ER & EER',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: NoSQL',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: Normalization',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: SQL',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: Security',
#  'UEF Moodle > Advanced Data Management Systems (THJ) > Self-assessment: Transactions & Triggers & Optimization',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > RyhmÃ¤tyÃ¶alue',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 12',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 14',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 18',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 2',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 20',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 4',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > TehtÃ¤vÃ¤ 9',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > Uutiset',
#  'UEF Moodle > Ihminen ja vuorovaikutteinen teknologia > Yleinen keskustelu ja palaute',
#  'Комбиниран тест за основни знания върху Тема 3 и Тема 5 > Attempt',
#  'ПОВТОРЕН Тест Електронно обучение > Attempt',
#  'Тест Електронно обучение > Attempt',
#  'Тест за установяване на запознаването с материалите за седмицата > Attempt',
#  'Тест за установяване на предварителното запознаване с материалите за седмицата > Attempt'}

# %% [markdown]
# # TODO: Try to categorize the activities' s context
